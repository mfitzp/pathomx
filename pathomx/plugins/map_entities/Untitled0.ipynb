# %%
dir()
# Out:
# ['ALLOW_THREADS',
#  'Annotation',
#  'Arrow',
#  'Artist',
#  'AutoLocator',
#  'Axes',
#  'BUFSIZE',
#  'Button',
#  'CLIP',
#  'Circle',
#  'ComplexWarning',
#  'DAILY',
#  'DataSource',
#  'DateFormatter',
#  'DateLocator',
#  'DayLocator',
#  'ERR_CALL',
#  'ERR_DEFAULT',
#  'ERR_DEFAULT2',
#  'ERR_IGNORE',
#  'ERR_LOG',
#  'ERR_PRINT',
#  'ERR_RAISE',
#  'ERR_WARN',
#  'FLOATING_POINT_SUPPORT',
#  'FPE_DIVIDEBYZERO',
#  'FPE_INVALID',
#  'FPE_OVERFLOW',
#  'FPE_UNDERFLOW',
#  'FR',
#  'False_',
#  'Figure',
#  'FigureCanvasBase',
#  'FixedFormatter',
#  'FixedLocator',
#  'FormatStrFormatter',
#  'Formatter',
#  'FuncFormatter',
#  'GridSpec',
#  'HOURLY',
#  'HourLocator',
#  'In',
#  'IndexDateFormatter',
#  'IndexLocator',
#  'Inf',
#  'Infinity',
#  'LinAlgError',
#  'Line2D',
#  'LinearLocator',
#  'Locator',
#  'LogFormatter',
#  'LogFormatterExponent',
#  'LogFormatterMathtext',
#  'LogLocator',
#  'MAXDIMS',
#  'MINUTELY',
#  'MO',
#  'MONTHLY',
#  'MachAr',
# ...
